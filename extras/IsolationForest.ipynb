# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest

# %%
data = {
    'salary': [26100, 73188, 3333333333, 14623, 44444444444, 95759, 22368, 90715, 18507, 11559]
}

# %%
df = pd.DataFrame(data)

# %%
df.values
# Out:
# array([[      26100],
#        [      73188],
#        [ 3333333333],
#        [      14623],
#        [44444444444],
#        [      95759],
#        [      22368],
#        [      90715],
#        [      18507],
#        [      11559]])

# %%
model = IsolationForest(n_estimators=50, max_samples='auto', contamination=float(0.1), max_features=1.0)

# %%
model.fit(df[['salary']])
# Out:
# IsolationForest(contamination=0.1, n_estimators=50)

# %%
df['scores'] = model.decision_function(df[['salary']])
df['anomaly'] = model.predict(df[['salary']])
df
# Out:
#         salary    scores  anomaly
# 0        26100  0.322775        1
# 1        73188  0.271397        1
# 2   3333333333  0.013114        1
# 3        14623  0.342512        1
# 4  44444444444 -0.118028       -1
# 5        95759  0.275040        1
# 6        22368  0.342036        1
# 7        90715  0.293659        1
# 8        18507  0.344250        1
# 9        11559  0.306510        1

# %%
anomaly = df[df['anomaly'] == -1]
anomaly
# Out:
#         salary    scores  anomaly
# 4  44444444444 -0.118028       -1
